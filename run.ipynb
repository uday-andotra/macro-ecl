# %% [markdown]
# # macro-ecl execution
# Calls `src.orchestrate.run_all`. Quantitative path does not need an API key.

# %%
from src.orchestrate import run_all
from IPython.display import Markdown, display

out = run_all(genai=False)
print('PWECL', out['results']['Probability_Weighted_ECL'])
print(out['metrics'])
display(Markdown(out['report_text'][:2500]))
# Out:
# RAW FILES used_mode=configured
#   loans : /Users/udayveersinghandotra/macro-ecl/data/raw/sba_raw.csv
#   macros: /Users/udayveersinghandotra/macro-ecl/data/raw/historical_macro_data.csv  (expected FRED GDPC1 + UNRATE extract)
# Loan tape layout=kaggle_sba_national file=/Users/udayveersinghandotra/macro-ecl/data/raw/sba_raw.csv rows=899164
# Kaggle SBAnational.csv has no borrower financial statements. leverage = 1 - SBA_Appv/GrAppv; liquidity_ratio = log1p(NoEmp)/4; collateral = EAD if Term>=240m else 0.5*EAD; default_flag from MIS_Status CHGOFF or ChgOffPrinGr>0; loss_severity = ChgOffPrinGr/EAD on defaults.
# Macro loaded rows=105 quarterly=True growth_nonnull=104 2000-01-01→2026-04-01
# LASSO quarterly panel rows=104
# asof_date missing on 6 rows; filled with last FRED observation
# Processed tape: /Users/udayveersinghandotra/macro-ecl/data/processed/sba_portfolio_tape.csv rows=897167 lags=['realgdp_growth_lag_1Q', 'unemp_lag_1Q'] lasso_alpha=10.0000
# LASSO lag table (top 8):
#             candidate  coef  abs_weight  selected
# realgdp_growth_lag_1Q   0.0         0.0      True
# realgdp_growth_lag_2Q   0.0         0.0     False
# realgdp_growth_lag_3Q  -0.0         0.0     False
# realgdp_growth_lag_4Q  -0.0         0.0     False
#          unemp_lag_1Q  -0.0         0.0      True
#          unemp_lag_2Q  -0.0         0.0     False
#          unemp_lag_3Q  -0.0         0.0     False
#          unemp_lag_4Q  -0.0         0.0     False
#
# === PROCESSED TAPE ===
#   rows                 897167
#   cols                 32
#   default_rate         0.181061
#   ead_sum              180,867,103,981.00
#   ead_p50              100,000
#   maturity_mean        9.23774
#   asof_min             1970-02-26 00:00:00
#   asof_max             2014-12-31 00:00:00
#   source               kaggle_sba_national
#   leverage_mean        0.290302
#   guarantee_mean       0.709698
#   by default_flag:
#                count           sum
# default_flag
# 0             734725  1.597257e+11
# 1             162442  2.114142e+10
# Macro loaded rows=105 quarterly=True growth_nonnull=104 2000-01-01→2026-04-01
# Scenarios (VAR(p=2)) written to /Users/udayveersinghandotra/macro-ecl/data/scenarios/macro_forecasts.csv
# scenario_name  realgdp_growth    unemp  realgdp_growth_lag_1Q  unemp_lag_1Q
#      baseline        0.002351 4.688727               0.002351      4.688727
#       adverse       -0.017649 6.188727              -0.017649      6.188727
#        severe       -0.047649 7.688727              -0.047649      7.688727
#
# === HOLDOUT PD ===
# HGB    {'n': 269151, 'default_rate': 0.18106193177807253, 'mean_pred': 0.18109944324093125, 'brier': 0.1391972140355381, 'auc': 0.6823915641422879, 'calibration_slope': 0.9876715101995293}
# Logit  {'n': 269151, 'default_rate': 0.18106193177807253, 'mean_pred': 0.18114869854848967, 'brier': 0.14083330911535327, 'auc': 0.666780693366687, 'calibration_slope': 1.0103564396904439}
# Decile calibration (1=low PD, 10=high):
#             n  default_rate  mean_pred
# decile
# 0       26987      0.026531   0.024253
# 1       31871      0.097926   0.095734
# 2       22305      0.095270   0.107348
# 3       30731      0.113599   0.125570
# 4       24891      0.150898   0.148331
# 5       25415      0.185048   0.176487
# 6       26646      0.255085   0.241728
# 7       27629      0.291505   0.271073
# 8       29870      0.302611   0.295592
# 9       22806      0.303911   0.344063
#
# Feature means by default_flag (train):
#               leverage  liquidity_ratio  realgdp_growth_lag_1Q  unemp_lag_1Q
# default_flag
# 0             0.275922         0.474129               0.006232      5.407616
# 1             0.355505         0.394809               0.006041      5.192327
#
# === STRESS ENGINE ===
# PIT PD = HGB only (no overlay)
#   [baseline] ECL=$6,754,141,038  cov=3.73%  PD_raw=24.64% PD=24.64%  LGD=11.22%  S1/S2/S3=86.1%/13.9%/0.0%  dU=+0.00 dG=+0.000
#   [adverse] ECL=$6,861,212,636  cov=3.79%  PD_raw=24.85% PD=24.85%  LGD=11.72%  S1/S2/S3=85.8%/14.2%/0.0%  dU=+1.50 dG=-0.020
#   [severe] ECL=$6,942,308,291  cov=3.84%  PD_raw=25.01% PD=25.01%  LGD=12.47%  S1/S2/S3=85.7%/14.3%/0.0%  dU=+3.00 dG=-0.050
#
# === SCENARIO BOOK ===
# scenario                  ECL      cov       PD      LGD      S1      S2      S3
# baseline        6,754,141,038   3.73%  24.64%  11.22%  86.1%  13.9%   0.0%
# adverse         6,861,212,636   3.79%  24.85%  11.72%  85.8%  14.2%   0.0%
# severe          6,942,308,291   3.84%  25.01%  12.47%  85.7%  14.3%   0.0%
# PWECL 6,823,895,968.05  weight_sum=1.0
# Wrote reports/figures/stress_dashboard.png
# Wrote reports/figures/pd_shift.png
# Wrote reports/figures/ecl_by_stage.png
# GenAI off: no OPENAI_API_KEY
# Wrote reports/ecl_macro_SR117_Final.pdf and reports/ecl_macro_SR117_Final.md
# Wrote /Users/udayveersinghandotra/macro-ecl/reports/last_run.json
# PWECL 6823895968.047734
# {'model': {'n': 269151, 'default_rate': 0.18106193177807253, 'mean_pred': 0.18109944324093125, 'brier': 0.1391972140355381, 'auc': 0.6823915641422879, 'calibration_slope': 0.9876715101995293}, 'challenger_logit': {'n': 269151, 'default_rate': 0.18106193177807253, 'mean_pred': 0.18114869854848967, 'brier': 0.14083330911535327, 'auc': 0.666780693366687, 'calibration_slope': 1.0103564396904439}, 'label_note': 'tape default_flag (Kaggle CHGOFF/PIF if layout detected; else as cleaned)', 'run_id': '42a6409dca564815bec0553c0f5ec415'}
# **ECL run summary**
# Demo engine. Not a production or validated model.
#
# **Portfolio**
# Source: kaggle_sba_national
# Facilities: 897,167
# EAD: $180,867,103,981.00
# PWECL: $6,823,895,968.05
# Coverage: 3.77%
# MLflow: 42a6409dca564815bec0553c0f5ec415
# Macro lags: ['realgdp_growth_lag_1Q', 'unemp_lag_1Q']
#
# **Method**
# PD: 12m HGB + logit overlay vs baseline macros. LGD: hurdle logit x ridge, downturn floor.
# ECL: Stage 1 = 12m; Stage 2 = lifetime (constant hazard from PD_12m, cap 5y); Stage 3 = EAD x LGD.
# SICR: PIT PD vs origination PD (tape macros). Scenarios: VAR one-step + config shocks.
#
# **Holdout**
# HGB   n=269151  DR=18.11%  AUC=0.682  Brier=0.1392  slope=0.988
# Logit AUC=0.667  Brier=0.1408
#
# **Scenarios**
# Scenario     | ECL              | PIT PD | PIT LGD | S1     | S2     | S3
# baseline     | $6,754,141,037.93 | 24.64% |  11.22% |  86.1% |  13.9% |   0.0%
# adverse      | $6,861,212,636.30 | 24.85% |  11.72% |  85.8% |  14.2% |   0.0%
# severe       | $6,942,308,290.95 | 25.01% |  12.47% |  85.7% |  14.3% |   0.0%
#
# **Limits**
# Kaggle proxies only. HGB does not reprice with UNRATE; scenario PD barely moves.
# No performing-book 12m default; closed PIF/CHGOFF tape. FRED from 2000 only.
# Point scenarios, constant EAD, no CCF. Random holdout. Demo only. GenAI text is not a control.
#
# **Notes**
# None.
